# %% [markdown]
# ## mount to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/AICamp2023/MMPose
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AICamp2023/MMPose

# %% [markdown]
# ## install mmdet

# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv>=2.0.0rc3'
# !mim install "mmdet>=3.0.0rc6"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 7.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.3/374.3 kB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 28.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 24.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## install mmpose

# %%
# !rm -rf mmpose
# !git clone https://github.com/open-mmlab/mmpose.git -b tutorial2023
# %cd mmpose
# !pip install -v -e .
# %cd ..
# Out:
# Cloning into 'mmpose'...
# remote: Enumerating objects: 27394, done.
# remote: Counting objects: 100% (1216/1216), done.
# remote: Compressing objects: 100% (623/623), done.
# remote: Total 27394 (delta 652), reused 1007 (delta 574), pack-reused 26178
# Receiving objects: 100% (27394/27394), 30.08 MiB | 17.46 MiB/s, done.
# Resolving deltas: 100% (19325/19325), done.
# Updating files: 100% (1537/1537), done.
# /content/drive/MyDrive/AICamp2023/MMPose/mmpose
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/AICamp2023/MMPose/mmpose
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-urx1m9x7/mmpose.egg-info
#   writing /tmp/pip-pip-egg-info-urx1m9x7/mmpose.egg-info/PKG-INFO
# ...

# %%
# !pip uninstall numpy -y
# !pip install numpy
# Out:
# Found existing installation: numpy 1.22.4
# Uninstalling numpy-1.22.4:
#   Successfully uninstalled numpy-1.22.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 91.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
# ...

# %% [markdown]
# ## inference on single image

# %%
# !python mmpose/demo/topdown_demo_with_mmdet.py \
        Models/RTMdet/rtmdet_ear.py \
        Models/RTMdet/best_coco_bbox_mAP_epoch_110.pth \
        Models/RTMPose/rtmpose_ear.py \
        Models/RTMPose/best_PCK_epoch_175.pth \
        --input Test/test_image.jpg \
        --output-root Results \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.3 \
        --radius 36 \
        --thickness 30 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: Models/RTMdet/best_coco_bbox_mAP_epoch_110.pth
# Loads checkpoint by local backend from path: Models/RTMPose/best_PCK_epoch_175.pth
# 06/04 18:20:56 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/AICamp2023/MMPose/mmpose/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
#   warnings.warn('The predicted simcc values are normalized for '

# %% [markdown]
# ## inference on test video

# %%
# !python mmpose/demo/topdown_demo_with_mmdet.py \
        Models/RTMdet/rtmdet_ear.py \
        Models/RTMdet/best_coco_bbox_mAP_epoch_110.pth \
        Models/RTMPose/rtmpose_ear.py \
        Models/RTMPose/best_PCK_epoch_175.pth \
        --input Test/test_video.mp4 \
        --output-root Results \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.3 \
        --radius 16 \
        --thickness 10 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: Models/RTMdet/best_coco_bbox_mAP_epoch_110.pth
# Loads checkpoint by local backend from path: Models/RTMPose/best_PCK_epoch_175.pth
# 06/04 18:43:04 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/AICamp2023/MMPose/mmpose/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
#   warnings.warn('The predicted simcc values are normalized for '
